# %% [markdown]
# # HANA SSBM-Benchmark

# %%
from util import Analyser, Comparison
import re
#import pdb
LOG_PATH_ROOT="./"
analyser_col = Analyser(LOG_PATH_ROOT + "col_19.03.18.json")
analyser_row = Analyser(LOG_PATH_ROOT + "row_19.03.18.json")

# %% [markdown]
# ## Testumgebung

# %% [markdown]
# CPU: Intel(R) Core(TM) i7-6820HQ CPU @ 2.70GHz
#
# CPU Kerne: 4 (x2 Theads)
#
# RAM: 8GB

# %% [markdown]
# ## Row vs. Column Store

# %%
column_benchmark = analyser_col.get_column_benchmark()
row_benchmark = analyser_row.get_row_benchmark()
comparison = Comparison(column_benchmark, row_benchmark)

comparison.set_title("Row- vs. Column Store Comparison")
comparison.compare_visually()
comparison.compare_bar_plot()
# Out:
# > /home/kristina/git/SSBM-HANA/analyser/util/analyser.py(233)compare_bar_plot()
# -> values = [stat.get_all_times() for stat in statistical.get_repetitions()]
# (Pdb) statistical.get_repetitions()
# [[{'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.sql', 'times': ' 433857;17100;8695;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.1.sql', 'times': ' 29425;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.2.sql', 'times': ' 8852;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.3.sql', 'times': ' 5594;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.sql', 'times': ' 721427;231;18951;98;5692;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.1.sql', 'times': ' 42020;154;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.2.sql', 'times': ' 18760;97;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.3.sql', 'times': ' 5942;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.sql', 'times': ' 205122;148;21282;272;6757;7428;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.1.sql', 'times': ' 133792;155;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.2.sql', 'times': ' 22883;276;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.3.sql', 'times': ' 7190;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.4.sql', 'times': ' 6582;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.sql', 'times': ' 167484;266;88445;121;14721;276;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.1.sql', 'times': ' 78825;87;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.2.sql', 'times': ' 80732;119;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.3.sql', 'times': ' 18407;316;'}], [{'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.sql', 'times': ' 17691;8235;5019;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.1.sql', 'times': ' 23176;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.2.sql', 'times': ' 8403;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.3.sql', 'times': ' 5267;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.sql', 'times': ' 44556;154;19961;95;5963;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.1.sql', 'times': ' 45332;155;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.2.sql', 'times': ' 20537;97;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.3.sql', 'times': ' 6102;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.sql', 'times': ' 136824;148;21416;285;7501;6752;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.1.sql', 'times': ' 126688;144;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.2.sql', 'times': ' 20922;314;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.3.sql', 'times': ' 6866;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.4.sql', 'times': ' 6410;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.sql', 'times': ' 83417;93;83250;114;14629;290;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.1.sql', 'times': ' 81236;93;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.2.sql', 'times': ' 78927;116;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.3.sql', 'times': ' 15178;282;'}], [{'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.sql', 'times': ' 18998;8143;5064;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.1.sql', 'times': ' 22867;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.2.sql', 'times': ' 8167;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.3.sql', 'times': ' 5093;'}, {'Type': 'exec_file', 'Filename': './sql/ ...
# (Pdb) statistical.count_repetitions()
# 10
# (Pdb) statistical.get_repetitions()[1]
# [{'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.sql', 'times': ' 17691;8235;5019;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.1.sql', 'times': ' 23176;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.2.sql', 'times': ' 8403;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q1_bench/q1.3.sql', 'times': ' 5267;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.sql', 'times': ' 44556;154;19961;95;5963;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.1.sql', 'times': ' 45332;155;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.2.sql', 'times': ' 20537;97;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q2_bench/q2.3.sql', 'times': ' 6102;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.sql', 'times': ' 136824;148;21416;285;7501;6752;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.1.sql', 'times': ' 126688;144;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.2.sql', 'times': ' 20922;314;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.3.sql', 'times': ' 6866;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q3_bench/q3.4.sql', 'times': ' 6410;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.sql', 'times': ' 83417;93;83250;114;14629;290;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.1.sql', 'times': ' 81236;93;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.2.sql', 'times': ' 78927;116;'}, {'Type': 'exec_file', 'Filename': './sql/benchmark_noolap/q4_bench/q4.3.sql', 'times': ' 15178;282;'}]
# (Pdb) statistical.get_repetitions()[1].get_all_times()
# *** AttributeError: 'list' object has no attribute 'get_all_times'
# (Pdb) statistical.get_repetitions()[1][1].get_all_times()
# *** AttributeError: 'dict' object has no attribute 'get_all_times'
# (Pdb) statistical.get_repetitions().get_all_times()
# *** AttributeError: 'list' object has no attribute 'get_all_times'
# (Pdb) statistical.get_all_times()
# <generator object Benchmark.get_all_times at 0x7f9425e57e08>
